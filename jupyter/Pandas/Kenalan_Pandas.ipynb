# %% [markdown]
# ## Pandas

# %% [markdown]
# #### adalah library di python yang di gunakan untuk data anlysis dan manipulation, dibangun diatas numpy, dengan pandas maka python akan menjadi seperti R

# %%
import pandas as pd

# %%
kapal = pd.read_csv('csv/kapal_titanic.csv')

# %%
kapal.head() #mengambil 5 awal
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
kapal.tail() #mengambil 5 akhir
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
#mengekspor data
kapal.to_csv('datacsv.csv', index = False) #indeks nya biar tidak di ikutkan

# %%
pd.read_csv('datacsv.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
kapal.to_excel('dataexcel.xlsx', index = False, sheet_name = "test1")

# %%
pd.read_excel('dataexcel.xlsx')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
#membaca file html
data_html = pd.read_html('https://en.wikipedia.org/wiki/London')

# %%
type(data_html)
# Out:
# list

# %%
#agar lebih mudah dibaca
data_html[0]
# Out:
#                                                London  \
# 0                                        Capital city
# 1   Clockwise from top: City of London in the fore...
# 2   .mw-parser-output .locmap .od{position:absolut...
# 3   Coordinates: .mw-parser-output .geo-default,.m...
# 4                                     Sovereign state
# 5                                             Country
# 6                                              Region
# 7                                 Ceremonial counties
# 8                          Local government districts
# 9                                   Settled by Romans
# 10                                         Government
# 11                                             • Type
# 12                                             • Body
# 13                                  • London Assembly
# 14                                    • UK Parliament
# 15                                               Area
# ...

# %%
from sqlalchemy import create_engine

# %%
#untuk megimpor ke format sql
mesin = create_engine('sqlite:///:memory:')

# %%
kapal.to_sql('sql',mesin)
# Out:
# 891

# %%
pd.read_sql('datasql',mesin)
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886    886         0       2    male  27.0      0      0  13.0000        S
# 887    887         1       1  female  19.0      0      0  30.0000        S
# 888    888         0       3  female   NaN      1      2  23.4500        S
# 889    889         1       1    male  26.0      0      0  30.0000        C
# 890    890         0       3    male  32.0      0      0   7.7500        Q
#
#      deck
# 0    None
# 1       C
# 2    None
# 3       C
# ...
